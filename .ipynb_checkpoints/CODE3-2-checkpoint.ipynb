# %% [markdown]
# # Write a program to go through 1000 random integers and check whether they are even or prime. In order to create a list of 1000 random integers, you can write the following statement:
# # import numpy as np
# # random_integers = np.random.randint(low=0, high=2000, size=(1000,))
# # Now pass the list of these 1000 random integers to a user defined function called even_prime_list_creation. This function will accept a list of 1000 random integers and return two lists of even as well as prime numbers. Make sure that your function does this in a recursive manner (remember that you can't use loop to go through each number in a list of 1000 random integers, that has to be done in a recursive manner)
# # Now, in order to create a list of even as well as prime numbers, even_prime_list_creation should know that which number is an even number and which number is a prime number. Well even number is easy to check so your function even_prime_list_creation can itself check whether the number is even or not but in order to check whether the number is prime or not, even_prime_list_creation is going to call another function called is_prime. This, is_prime function will accept a number and check whether it's prime or not in a recursive manner (again you can't use a loop to check whether the number is prime or not, that has to be done in a recursive manner) and is going to return True or False accordingly.
# # So, both functions should do their job in a recursive manner. And the final outcome should be two lists, one of even number and one of prime numbers.

# %%
import numpy as np
randomintegers = np.random.randint(low=1, high=2000, size=1000)

# %%
randomintegers
# Out:
# array([ 777,  513,  576,   14,  316,  596,  511, 1805, 1563,  324, 1041,
#          99, 1149, 1054,  273, 1908, 1954, 1521, 1380, 1242, 1368, 1624,
#        1164,   90, 1100,  535,  873, 1670,  468,  669, 1421,  442, 1620,
#        1988,  771, 1028, 1425, 1593,   39,  236, 1579,  615, 1221,  939,
#         546,  900,  648, 1663, 1470,  266, 1066, 1968,  719,  927, 1720,
#         262,  904,  629, 1801, 1737, 1427,  396, 1871, 1579, 1855,  508,
#         490,  299, 1634,  644, 1385,  984, 1609,  487,  676,  256,  710,
#        1762, 1457, 1981,  137, 1537,  978,  618, 1977, 1137,  929,  752,
#         980,  652,  567,  826, 1878, 1843, 1008,  319,  916,   91,  338,
#        1261, 1036,  943,  795,  120, 1461, 1197, 1064, 1470,   71,  599,
#          51, 1727,  792, 1329, 1451,  527,  947, 1348,  176,  658, 1769,
#        1803, 1020, 1399, 1832,  201, 1538, 1335, 1422,  713,  850, 1451,
#        1616, 1129, 1191,  536, 1871,  699,  711, 1497,  455,  203, 1928,
#          33,  895,  557,  852,  830,  265, 1260, 1577,  179,  886, 1725,
#        1343,  127, 1270, 1039, 1693, 1552, 1102,   73,  647, 1569,  694,
#         653,  331, 1860,  378, 1667,  954,  843,  608, 1117,  234,  192,
#         255, 1948,  579, 1043, 1975,  710, 1702,  318,  504,  912,  634,
#         722,  858,  142, 1220,  384,  687, 1652,  849,  734, 1201, 1974,
#         919,  959,  189, 1071,  245,  277,  559,  119,   89, 1282, 1850,
#        1664, 1423, 1304, 1017,  819, 1146,   48,  273,  182,  358, 1905,
#         265, 1223, 1366,  738,  393, 1463, 1237, 1790,  447,  562,  690,
#        1922,  383,  662, 1955,  622,  361, 1313,   63,  281,  279,  322,
#        1739,  842,  362,   74, 1091,  999, 1565, 1713, 1261, 1566,  320,
#        1204, 1705,  570,  697,  862, 1475, 1668, 1331,  433, 1648,  245,
#          49,  570,  231, 1047,  957,  631, 1411, 1541, 1497, 1779,  636,
#         171,  235,  824,  113,  566, 1455, 1594, 1210, 1084,  667, 1231,
#        1383, 1409,  574, 1043,  274,  872,  949,  803,  573,  980,  925,
#        1005,  629, 1880, 1972, 1995, 1866, 1462,  753, 1454, 1739,  520,
#        1968,  531,  283,  146, 1062,  364, 1457,  859, 1761,  108,  644,
#         795,  376, 1539, 1256,  392,  858,   16, 1367,  649,   97,  583,
#         288, 1969,  433,  753, 1782,    9,  662,   56, 1221, 1335,  435,
#         227,  212, 1397, 1911, 1822, 1404,  410, 1259,  338, 1634,  584,
#        1070,  601, 1652,  117,  302, 1915, 1797,  469,  860, 1456,  932,
#         478,  483,  447,  947,  979,  336, 1665, 1982,  468,  831,  747,
#        1503,  721, 1080, 1404, 1607, 1780, 1296,  505, 1042,  131,  169,
#        1107,  890,  700,  968, 1688,   48, 1595, 1175, 1285,  334,  239,
#        1160,  556, 1670, 1210,  951, 1565,  810,  876, 1998, 1946, 1084,
#        1120, 1862,  990, 1774, 1926, 1176,  849,  785, 1882, 1230,  186,
#        1099,   20,  176,  370,  319,  868, 1198, 1063, 1521, 1355, 1073,
#        1529, 1822,   68,  119,  905, 1202,  432,  621,  239,  544, 1191,
#         897,  627, 1311,  696,  821, 1852, 1333,  497,  703, 1169, 1962,
#        1806,  728,  512, 1593,  927,  896, 1435,  667, 1070, 1527,  795,
#        1663,  537, 1667, 1669,  813, 1008,   38,  397, 1029, 1799,  664,
#        1022,  977, 1947, 1816,  467, 1941,  925,  200,  889, 1111, 1110,
#        1639,  631,  312,  525,  799, 1322, 1694,  459,  501,  941, 1480,
#         176,    7,  984, 1933,  695,  426, 1889, 1860, 1153, 1301,  887,
#         644,  808, 1303, 1537, 1654, 1465,  938,  950,  896,  512,  782,
#          93, 1548, 1723, 1990,  638,  431,  908,  922, 1923,  565,   73,
#        1559, 1030,   53, 1089,  617, 1208,  635, 1301,  194, 1754, 1349,
#         241, 1470, 1501,  473,  861,  593, 1783, 1261,  728, 1351, 1112,
#         452,  255, 1000, 1369, 1450,  860,  904,  875, 1786, 1699,  556,
#         337, 1881, 1902,  747, 1312,  412,  557, 1412, 1667, 1230,  468,
#          16,  757, 1189,  398,   72,  493,  220,  704,  412, 1326, 1841,
#         164,  999, 1001, 1976, 1377,  166,  582,  871, 1373, 1082,  467,
#        1759,  125, 1182,  665, 1246,  993,  698,  605, 1080, 1677,  200,
#         407, 1714,  704,  320, 1111, 1471,  269,  532, 1522,  326,  476,
#          96,   74,  546, 1712, 1996,  414, 1765,  993,  447,  982,  535,
#         315,  135, 1717,  568,  656, 1857, 1146, 1870,  157, 1445,  791,
#         689, 1637, 1810, 1141, 1363,  823,  680,  222, 1077,  491,  204,
#         218, 1532,  506,  660, 1074,  343,  373,  976, 1300, 1414,  243,
#        1036,  919, 1857, 1465,  137, 1253, 1076, 1570, 1216, 1509, 1207,
#        1835,  757,  635,  257, 1127,  251,  297, 1128,  983,  598, 1748,
#         951, 1841, 1211,  449,  105, 1677, 1709,  175, 1176, 1957, 1852,
#        1059,  402, 1328,   43, 1207,  935, 1071, 1237,  752, 1912, 1643,
#         656,  790,  888, 1301, 1180,  785, 1083, 1963, 1423,  231, 1242,
#        1026, 1849,  857, 1930,   19, 1597,  253,  479,  195,  986,  679,
#        1516, 1132, 1794, 1216,  676, 1394,  808, 1892,  713,  539,  386,
#        1568, 1673,  463, 1865,  738, 1663, 1011, 1591, 1479,  491, 1546,
#        1042,  337,  723,  817,  939, 1095,  588, 1800, 1062,  839, 1192,
#        1943,   93,  901,  138,  347,  977, 1968, 1774,  772,  957,  988,
#         591,  331, 1389, 1097, 1924, 1492, 1102,  403, 1397,  734, 1920,
#        1744,  116,  950,  263,  321,  835, 1040, 1740,  372, 1203, 1171,
#        1235,  837, 1295,  212,  858,  787,  926,  876, 1286,  195, 1196,
#         911, 1357, 1481, 1105,  541, 1836, 1782,  639, 1765, 1893,  473,
#         160,  199, 1278, 1774,  367, 1091, 1297,  484,  737,  881, 1093,
#        1172, 1944, 1127,  915,  154,  126, 1485, 1414,  210,  358, 1521,
#        1597, 1520, 1077,  891,  408, 1842,  773, 1771,  476, 1169,  954,
#        1554, 1536,  629, 1144,  435,  714,  793,  632, 1082,  778, 1071,
#        1181,  439,  170, 1160,  129, 1748, 1681,  666, 1016, 1554, 1197,
#         241,  872,  106, 1141,   55,  379, 1027, 1588,  903, 1398, 1313,
#         724,  222,   55,  558,   77,  337,  287, 1490,  488,  535, 1894,
#        1938,  977,  245,  459, 1887,  121,  910,  525, 1589, 1213,  899,
#         853,  695,  858, 1324,  542, 1729,  653, 1702,   68,   12, 1637,
#        1895, 1868, 1931, 1315, 1972, 1269, 1742,  366,  983, 1165, 1519,
#        1861,  114,  735, 1466,  865, 1859, 1318, 1608,  185,  363,  113,
#         262,  304,  512,  941, 1511,  303, 1289, 1374, 1853, 1618,  875,
#        1463, 1761, 1521, 1071,  917, 1517, 1672, 1134,  309, 1123, 1478,
#        1563,  936,  341, 1681,  441,  314, 1879, 1130, 1496,  390,   60,
#         167,  394, 1433, 1196, 1883, 1256,  841,  160, 1401, 1780,  348,
#         763,  919, 1757, 1315,  788, 1172,  405, 1701, 1719, 1241,  571,
#         842, 1687,  670, 1919,   97,  890,  384,  438, 1208, 1900])

# %%
def prime(x,divisor):
    if x == 1:
        return "Prime"
    if x == divisor:
        return "Prime"
    if x % divisor == 0:
        return "Not Prime"
    divisor = divisor + 1
    P = prime(x, divisor)
    return P

# %%
def num(x):
    if x % 2 == 0:
        return "Even"
    else:
        result = prime(x,2)
        return result

# %%
EVEN=[]
PRIME=[]
def even_prime_list_creation(randomintegers,EVEN,PRIME,index):
    if index == 1000 :
        return EVEN,PRIME
    else:
        if num(randomintegers[index]) == "Even":
            EVEN.append(randomintegers[index])
        if num(randomintegers[index]) == "Prime":
            PRIME.append(randomintegers[index]) 
        index = index + 1
        even,prime = even_prime_list_creation(randomintegers,EVEN,PRIME,index)
        return even,prime

# %%
EVEN,PRIME = even_prime_list_creation(randomintegers,EVEN,PRIME,0)

# %%
EVEN
# Out:
# [576,
#  14,
#  316,
#  596,
#  324,
#  1054,
#  1908,
#  1954,
#  1380,
#  1242,
#  1368,
#  1624,
#  1164,
#  90,
#  1100,
#  1670,
#  468,
#  442,
#  1620,
#  1988,
#  1028,
#  236,
#  546,
#  900,
#  648,
#  1470,
#  266,
#  1066,
#  1968,
#  1720,
#  262,
#  904,
#  396,
#  508,
#  490,
#  1634,
#  644,
#  984,
#  676,
#  256,
#  710,
#  1762,
#  978,
#  618,
#  752,
#  980,
#  652,
#  826,
#  1878,
#  1008,
#  916,
#  338,
#  1036,
#  120,
#  1064,
#  1470,
#  792,
#  1348,
#  176,
#  658,
#  1020,
#  1832,
#  1538,
#  1422,
#  850,
#  1616,
#  536,
#  1928,
#  852,
#  830,
#  1260,
#  886,
#  1270,
#  1552,
#  1102,
#  694,
#  1860,
#  378,
#  954,
#  608,
#  234,
#  192,
#  1948,
#  710,
#  1702,
#  318,
#  504,
#  912,
#  634,
#  722,
#  858,
#  142,
#  1220,
#  384,
#  1652,
#  734,
#  1974,
#  1282,
#  1850,
#  1664,
#  1304,
#  1146,
#  48,
#  182,
#  358,
#  1366,
#  738,
#  1790,
#  562,
#  690,
#  1922,
#  662,
#  622,
#  322,
#  842,
#  362,
#  74,
#  1566,
#  320,
#  1204,
#  570,
#  862,
#  1668,
#  1648,
#  570,
#  636,
#  824,
#  566,
#  1594,
#  1210,
#  1084,
#  574,
#  274,
#  872,
#  980,
#  1880,
#  1972,
#  1866,
#  1462,
#  1454,
#  520,
#  1968,
#  146,
#  1062,
#  364,
#  108,
#  644,
#  376,
#  1256,
#  392,
#  858,
#  16,
#  288,
#  1782,
#  662,
#  56,
#  212,
#  1822,
#  1404,
#  410,
#  338,
#  1634,
#  584,
#  1070,
#  1652,
#  302,
#  860,
#  1456,
#  932,
#  478,
#  336,
#  1982,
#  468,
#  1080,
#  1404,
#  1780,
#  1296,
#  1042,
#  890,
#  700,
#  968,
#  1688,
#  48,
#  334,
#  1160,
#  556,
#  1670,
#  1210,
#  810,
#  876,
#  1998,
#  1946,
#  1084,
#  1120,
#  1862,
#  990,
#  1774,
#  1926,
#  1176,
#  1882,
#  1230,
#  186,
#  20,
#  176,
#  370,
#  868,
#  1198,
#  1822,
#  68,
#  1202,
#  432,
#  544,
#  696,
#  1852,
#  1962,
#  1806,
#  728,
#  512,
#  896,
#  1070,
#  1008,
#  38,
#  664,
#  1022,
#  1816,
#  200,
#  1110,
#  312,
#  1322,
#  1694,
#  1480,
#  176,
#  984,
#  426,
#  1860,
#  644,
#  808,
#  1654,
#  938,
#  950,
#  896,
#  512,
#  782,
#  1548,
#  1990,
#  638,
#  908,
#  922,
#  1030,
#  1208,
#  194,
#  1754,
#  1470,
#  728,
#  1112,
#  452,
#  1000,
#  1450,
#  860,
#  904,
#  1786,
#  556,
#  1902,
#  1312,
#  412,
#  1412,
#  1230,
#  468,
#  16,
#  398,
#  72,
#  220,
#  704,
#  412,
#  1326,
#  164,
#  1976,
#  166,
#  582,
#  1082,
#  1182,
#  1246,
#  698,
#  1080,
#  200,
#  1714,
#  704,
#  320,
#  532,
#  1522,
#  326,
#  476,
#  96,
#  74,
#  546,
#  1712,
#  1996,
#  414,
#  982,
#  568,
#  656,
#  1146,
#  1870,
#  1810,
#  680,
#  222,
#  204,
#  218,
#  1532,
#  506,
#  660,
#  1074,
#  976,
#  1300,
#  1414,
#  1036,
#  1076,
#  1570,
#  1216,
#  1128,
#  598,
#  1748,
#  1176,
#  1852,
#  402,
#  1328,
#  752,
#  1912,
#  656,
#  790,
#  888,
#  1180,
#  1242,
#  1026,
#  1930,
#  986,
#  1516,
#  1132,
#  1794,
#  1216,
#  676,
#  1394,
#  808,
#  1892,
#  386,
#  1568,
#  738,
#  1546,
#  1042,
#  588,
#  1800,
#  1062,
#  1192,
#  138,
#  1968,
#  1774,
#  772,
#  988,
#  1924,
#  1492,
#  1102,
#  734,
#  1920,
#  1744,
#  116,
#  950,
#  1040,
#  1740,
#  372,
#  212,
#  858,
#  926,
#  876,
#  1286,
#  1196,
#  1836,
#  1782,
#  160,
#  1278,
#  1774,
#  484,
#  1172,
#  1944,
#  154,
#  126,
#  1414,
#  210,
#  358,
#  1520,
#  408,
#  1842,
#  476,
#  954,
#  1554,
#  1536,
#  1144,
#  714,
#  632,
#  1082,
#  778,
#  170,
#  1160,
#  1748,
#  666,
#  1016,
#  1554,
#  872,
#  106,
#  1588,
#  1398,
#  724,
#  222,
#  558,
#  1490,
#  488,
#  1894,
#  1938,
#  910,
#  858,
#  1324,
#  542,
#  1702,
#  68,
#  12,
#  1868,
#  1972,
#  1742,
#  366,
#  114,
#  1466,
#  1318,
#  1608,
#  262,
#  304,
#  512,
#  1374,
#  1618,
#  1672,
#  1134,
#  1478,
#  936,
#  314,
#  1130,
#  1496,
#  390,
#  60,
#  394,
#  1196,
#  1256,
#  160,
#  1780,
#  348,
#  788,
#  1172,
#  842,
#  670,
#  890,
#  384,
#  438,
#  1208,
#  1900,
#  576,
#  14,
#  316,
#  596,
#  324,
#  1054,
#  1908,
#  1954,
#  1380,
#  1242,
#  1368,
#  1624,
#  1164,
#  90,
#  1100,
#  1670,
#  468,
#  442,
#  1620,
#  1988,
#  1028,
#  236,
#  546,
#  900,
#  648,
#  1470,
#  266,
#  1066,
#  1968,
#  1720,
#  262,
#  904,
#  396,
#  508,
#  490,
#  1634,
#  644,
#  984,
#  676,
#  256,
#  710,
#  1762,
#  978,
#  618,
#  752,
#  980,
#  652,
#  826,
#  1878,
#  1008,
#  916,
#  338,
#  1036,
#  120,
#  1064,
#  1470,
#  792,
#  1348,
#  176,
#  658,
#  1020,
#  1832,
#  1538,
#  1422,
#  850,
#  1616,
#  536,
#  1928,
#  852,
#  830,
#  1260,
#  886,
#  1270,
#  1552,
#  1102,
#  694,
#  1860,
#  378,
#  954,
#  608,
#  234,
#  192,
#  1948,
#  710,
#  1702,
#  318,
#  504,
#  912,
#  634,
#  722,
#  858,
#  142,
#  1220,
#  384,
#  1652,
#  734,
#  1974,
#  1282,
#  1850,
#  1664,
#  1304,
#  1146,
#  48,
#  182,
#  358,
#  1366,
#  738,
#  1790,
#  562,
#  690,
#  1922,
#  662,
#  622,
#  322,
#  842,
#  362,
#  74,
#  1566,
#  320,
#  1204,
#  570,
#  862,
#  1668,
#  1648,
#  570,
#  636,
#  824,
#  566,
#  1594,
#  1210,
#  1084,
#  574,
#  274,
#  872,
#  980,
#  1880,
#  1972,
#  1866,
#  1462,
#  1454,
#  520,
#  1968,
#  146,
#  1062,
#  364,
#  108,
#  644,
#  376,
#  1256,
#  392,
#  858,
#  16,
#  288,
#  1782,
#  662,
#  56,
#  212,
#  1822,
#  1404,
#  410,
#  338,
#  1634,
#  584,
#  1070,
#  1652,
#  302,
#  860,
#  1456,
#  932,
#  478,
#  336,
#  1982,
#  468,
#  1080,
#  1404,
#  1780,
#  1296,
#  1042,
#  890,
#  700,
#  968,
#  1688,
#  48,
#  334,
#  1160,
#  556,
#  1670,
#  1210,
#  810,
#  876,
#  1998,
#  1946,
#  1084,
#  1120,
#  1862,
#  990,
#  1774,
#  1926,
#  1176,
#  1882,
#  1230,
#  186,
#  20,
#  176,
#  370,
#  868,
#  1198,
#  1822,
#  68,
#  1202,
#  432,
#  544,
#  696,
#  1852,
#  1962,
#  1806,
#  728,
#  512,
#  896,
#  1070,
#  1008,
#  38,
#  664,
#  1022,
#  1816,
#  200,
#  1110,
#  312,
#  1322,
#  1694,
#  1480,
#  176,
#  984,
#  426,
#  1860,
#  644,
#  808,
#  1654,
#  938,
#  950,
#  896,
#  512,
#  782,
#  1548,
#  1990,
#  638,
#  908,
#  922,
#  1030,
#  1208,
#  194,
#  1754,
#  1470,
#  728,
#  1112,
#  452,
#  1000,
#  1450,
#  860,
#  904,
#  1786,
#  556,
#  1902,
#  1312,
#  412,
#  1412,
#  1230,
#  468,
#  16,
#  398,
#  72,
#  220,
#  704,
#  412,
#  1326,
#  164,
#  1976,
#  166,
#  582,
#  1082,
#  1182,
#  1246,
#  698,
#  1080,
#  200,
#  1714,
#  704,
#  320,
#  532,
#  1522,
#  326,
#  476,
#  96,
#  74,
#  546,
#  1712,
#  1996,
#  414,
#  982,
#  568,
#  656,
#  1146,
#  1870,
#  1810,
#  680,
#  222,
#  204,
#  218,
#  1532,
#  506,
#  660,
#  1074,
#  976,
#  1300,
#  1414,
#  1036,
#  1076,
#  1570,
#  1216,
#  1128,
#  598,
#  1748,
#  1176,
#  1852,
#  402,
#  1328,
#  752,
#  1912,
#  656,
#  790,
#  888,
#  1180,
#  1242,
#  1026,
#  1930,
#  986,
#  1516,
#  1132,
#  1794,
#  1216,
#  676,
#  1394,
#  808,
#  1892,
#  386,
#  1568,
#  738,
#  1546,
#  1042,
#  588,
#  1800,
#  1062,
#  1192,
#  138,
#  1968,
#  1774,
#  772,
#  988,
#  1924,
#  1492,
#  1102,
#  734,
#  1920,
#  1744,
#  116,
#  950,
#  1040,
#  1740,
#  372,
#  212,
#  858,
#  926,
#  876,
#  1286,
#  1196,
#  1836,
#  1782,
#  160,
#  1278,
#  1774,
#  484,
#  1172,
#  1944,
#  154,
#  126,
#  1414,
#  210,
#  358,
#  1520,
#  408,
#  1842,
#  476,
#  954,
#  1554,
#  1536,
#  1144,
#  714,
#  632,
#  1082,
#  778,
#  170,
#  1160,
#  1748,
#  666,
#  1016,
#  1554,
#  872,
#  106,
#  1588,
#  1398,
#  724,
#  222,
#  558,
#  1490,
#  488,
#  1894,
#  1938,
#  910,
#  858,
#  1324,
#  542,
#  1702,
#  68,
#  12,
#  1868,
#  1972,
#  1742,
#  366,
#  114,
#  1466,
#  1318,
#  1608,
#  262,
#  304,
#  512,
#  1374,
#  1618,
#  1672,
#  1134,
#  1478,
#  936,
#  314,
#  1130,
#  1496,
#  390,
#  60,
#  394,
#  1196,
#  1256,
#  160,
#  1780,
#  348,
#  788,
#  1172,
#  842,
#  670,
#  890,
#  384,
#  438,
#  1208,
#  1900]

# %%
PRIME
# Out:
# [1579,
#  1663,
#  719,
#  1801,
#  1427,
#  1871,
#  1579,
#  1609,
#  487,
#  137,
#  929,
#  71,
#  599,
#  1451,
#  947,
#  1399,
#  1451,
#  1129,
#  1871,
#  557,
#  179,
#  127,
#  1039,
#  1693,
#  73,
#  647,
#  653,
#  331,
#  1667,
#  1117,
#  1201,
#  919,
#  277,
#  89,
#  1423,
#  1223,
#  1237,
#  383,
#  281,
#  1091,
#  433,
#  631,
#  113,
#  1231,
#  1409,
#  283,
#  859,
#  1367,
#  97,
#  433,
#  227,
#  1259,
#  601,
#  947,
#  1607,
#  131,
#  239,
#  1063,
#  239,
#  821,
#  1663,
#  1667,
#  1669,
#  397,
#  977,
#  467,
#  631,
#  941,
#  7,
#  1933,
#  1889,
#  1153,
#  1301,
#  887,
#  1303,
#  1723,
#  431,
#  73,
#  1559,
#  53,
#  617,
#  1301,
#  241,
#  593,
#  1783,
#  1699,
#  337,
#  557,
#  1667,
#  757,
#  1373,
#  467,
#  1759,
#  1471,
#  269,
#  157,
#  1637,
#  823,
#  491,
#  373,
#  919,
#  137,
#  757,
#  257,
#  251,
#  983,
#  449,
#  1709,
#  43,
#  1237,
#  1301,
#  1423,
#  857,
#  19,
#  1597,
#  479,
#  463,
#  1663,
#  491,
#  337,
#  839,
#  347,
#  977,
#  331,
#  1097,
#  263,
#  1171,
#  787,
#  911,
#  1481,
#  541,
#  199,
#  367,
#  1091,
#  1297,
#  881,
#  1093,
#  1597,
#  773,
#  1181,
#  439,
#  241,
#  379,
#  337,
#  977,
#  1213,
#  853,
#  653,
#  1637,
#  1931,
#  983,
#  1861,
#  113,
#  941,
#  1511,
#  1289,
#  1123,
#  1879,
#  167,
#  1433,
#  919,
#  571,
#  97,
#  1579,
#  1663,
#  719,
#  1801,
#  1427,
#  1871,
#  1579,
#  1609,
#  487,
#  137,
#  929,
#  71,
#  599,
#  1451,
#  947,
#  1399,
#  1451,
#  1129,
#  1871,
#  557,
#  179,
#  127,
#  1039,
#  1693,
#  73,
#  647,
#  653,
#  331,
#  1667,
#  1117,
#  1201,
#  919,
#  277,
#  89,
#  1423,
#  1223,
#  1237,
#  383,
#  281,
#  1091,
#  433,
#  631,
#  113,
#  1231,
#  1409,
#  283,
#  859,
#  1367,
#  97,
#  433,
#  227,
#  1259,
#  601,
#  947,
#  1607,
#  131,
#  239,
#  1063,
#  239,
#  821,
#  1663,
#  1667,
#  1669,
#  397,
#  977,
#  467,
#  631,
#  941,
#  7,
#  1933,
#  1889,
#  1153,
#  1301,
#  887,
#  1303,
#  1723,
#  431,
#  73,
#  1559,
#  53,
#  617,
#  1301,
#  241,
#  593,
#  1783,
#  1699,
#  337,
#  557,
#  1667,
#  757,
#  1373,
#  467,
#  1759,
#  1471,
#  269,
#  157,
#  1637,
#  823,
#  491,
#  373,
#  919,
#  137,
#  757,
#  257,
#  251,
#  983,
#  449,
#  1709,
#  43,
#  1237,
#  1301,
#  1423,
#  857,
#  19,
#  1597,
#  479,
#  463,
#  1663,
#  491,
#  337,
#  839,
#  347,
#  977,
#  331,
#  1097,
#  263,
#  1171,
#  787,
#  911,
#  1481,
#  541,
#  199,
#  367,
#  1091,
#  1297,
#  881,
#  1093,
#  1597,
#  773,
#  1181,
#  439,
#  241,
#  379,
#  337,
#  977,
#  1213,
#  853,
#  653,
#  1637,
#  1931,
#  983,
#  1861,
#  113,
#  941,
#  1511,
#  1289,
#  1123,
#  1879,
#  167,
#  1433,
#  919,
#  571,
#  97]

# %%
len(EVEN)
# Out:
# 922

# %%
len(PRIME)
# Out:
# 326

# %% [markdown]
# # THE END
